# %%
import os
import time
import random; random.seed(0)
import numpy as np; np.random.seed(0)
import math

import matplotlib.pyplot as plt
plt.style.use('ggplot')
from PIL import Image

import ai2thor
import ai2thor_colab
from ai2thor_colab import plot_frames
from ai2thor.controller import Controller

from ai2thor.platform import CloudRendering
controller = Controller(platform=CloudRendering)

# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
from torch.distributions import Categorical

import clip

# Set random seeds for maintaining reproducibility
os.environ['PYTHONHASHSEED'] = str(0)
torch.backends.cudnn.deterministic = True

import warnings
warnings.filterwarnings('ignore')

# %%
from ppo import PPOAgent
from a2c import A2CAgent

from train import (
    process_inputs, random_policy, manual_control_policy, train_ppo, train_a2c
)

# %% [markdown]
# ## Set Environment

# %%
floor_index = random.randint(0, 30)
floor_index = 10

controller = Controller(
    agentMode="arm",
    massThreshold=None,
    visibilityDistance=0.50,
    scene=f"FloorPlan{floor_index}",

    # step sizes
    snapToGrid = False,
    gridSize=0.05,
    
    # image modalities
    renderInstanceSegmentation=False,
    renderDepthImage=False,
    renderSemanticSegmentation=False,
    renderNormalsImage=False,
    
    # camera properties
    width = 1280,
    height = 720,
    fieldOfView = 60,
    
    # set seed for reproducibility
    seed=90,
)

plot_frames(controller.last_event)
controller.reset(f"FloorPlan{floor_index}");

# %% [markdown]
# ## Set Configs

# %%
is_cuda = torch.cuda.is_available()

if is_cuda: device = torch.device('cuda')
else: device = torch.device('cpu')

state_dim = SCREEN_WIDTH = SCREEN_HEIGHT = 224 # Resnet's input size

# %%
action_space = ["MoveAgent", "RotateAgent", "MoveArm", "MoveArmBase", "LookUp", "LookDown"]

# %%
instruction = "Pick up the bread on the table"

# %% [markdown]
# ## Load Model

# %%
# Not implemented yet as the policy
ppo_agent = PPOAgent(state_dim=state_dim, action_dim = len(action_space))
a2c_agent = A2CAgent(state_dim=state_dim, action_dim = len(action_space))

# %% [markdown]
# ## Run Environment

# %%
random_policy(controller, action_space, instruction, num_steps=10)
# manual_control_policy(controller, action_space, instruction)
# train_ppo(controller, ppo_agent, action_space, state_dim, num_episodes=1000, max_timesteps=200)
# train_a2c(controller, a2c_agent, action_space, state_dim, num_episodes=1000, max_timesteps=200)

controller.stop()
# Out:
# Step 1: Action=MoveArmBase, Instruction: "Pick up the bread on the table", Similarity=0.1965
# Step 2: Action=MoveArmBase, Instruction: "Pick up the bread on the table", Similarity=0.1965
# Step 3: Action=LookUp, Instruction: "Pick up the bread on the table", Similarity=0.1862
# Step 4: Action=MoveArmBase, Instruction: "Pick up the bread on the table", Similarity=0.1862
# Step 5: Action=MoveArm, Instruction: "Pick up the bread on the table", Similarity=0.1862
# Step 6: Action=RotateAgent, Instruction: "Pick up the bread on the table", Similarity=0.1774
# Step 7: Action=MoveArm, Instruction: "Pick up the bread on the table", Similarity=0.1774
# Step 8: Action=LookUp, Instruction: "Pick up the bread on the table", Similarity=0.1774
# Step 9: Action=LookDown, Instruction: "Pick up the bread on the table", Similarity=0.1788

# %% [markdown]
# ---
